# %%
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import graph
import main

# %%
main.test()
# Out:
# A Coordinate : ( -6.898914 ,  107.612686 ) : Cartesian ( 3629.019315126758 ,  3725.6476542257033
# B Coordinate : ( -6.896861 ,  107.609609 ) : Cartesian ( 3645.7458801956504 ,  3719.8508096373007
# C Coordinate : ( -6.893749 ,  107.612943 ) : Cartesian ( 3641.270682104683 ,  3740.1478516361813
# D Coordinate : ( -6.888563 ,  107.608088 ) : Cartesian ( 3672.6165616688677 ,  3735.883837397132
# E Coordinate : ( -6.88733 ,  107.60936 ) : Cartesian ( 3670.98858482666 ,  3743.7413919466803
# F Coordinate : ( -6.882602 ,  107.611693 ) : Cartesian ( 3674.1550233859934 ,  3764.4990516017274
# G Coordinate : ( -6.876839 ,  107.617807 ) : Cartesian ( 3665.3866314578536 ,  3801.7411930261296
# H Coordinate : ( -6.893374 ,  107.618035 ) : Cartesian ( 3623.1289641944754 ,  3759.6266718945485
# I Coordinate : ( -6.899059 ,  107.616565 ) : Cartesian ( 3614.1694275437458 ,  3739.3128808782835
# 0.000000 409.254313 575.022088 0.000000 0.000000 0.000000 0.000000 853.314461 428.505537
# ...
