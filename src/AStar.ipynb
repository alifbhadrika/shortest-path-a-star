# %%
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook
sns.set()

# %%
G = nx.Graph()
G.add_edge('itb','sadikin', pos=(1,2))

# %%
plt.figure()
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="640">
