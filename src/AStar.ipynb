# %%
import main

# %%
main.start()
# Out:
# #### A* Shortest Path Finder ####
#
# PLACES AT DAGO
# [ 1 ] Sabuga
# [ 2 ] Sadikin
# [ 3 ] Borma
# [ 4 ] MonJu
# [ 5 ] Ciwalk
# [ 6 ] McdDago
# [ 7 ] Baltos
# [ 8 ] RSBorro
# [ 9 ] WarkopADD
# [ 10 ] AyamSPG
#
# THE SHORTEST PATH FROM  Sabuga  TO  Borma
# Sabuga --> Sadikin --> Borma
#
# WITH DISTANCE 1.581 KMs
